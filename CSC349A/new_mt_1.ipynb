# %% [markdown]
# 1.1a) an ill conditioned problem is one where a small relative error for the input value ie: x results in a large relative error in the output value y.
# 1.1b) any polynomial with multiplicity greater than 1. ie (x-1)^3. notice that when you put in x = 1.001, the actual x is 1, |1.001 - 1|/1 = 0.001 = 0.1% error = small. but this results in the error , which is 0.000000001 where the actual output is 0
# we get 0.000000001, so our error is approaching infinity!!
