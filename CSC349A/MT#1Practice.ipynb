# %%
import numpy as np

# %% [markdown]
# #1.1a) it is a problem where a small change in our input results in a large deviation for our output. ie: a relative error that is small for our input results in a large relative error for our output.
# #1.1b)
#
# 1.2): a)inaccurate (subtraction)
# b) accurate subtraction barely alters.
# c) accurate no longer subtraction.
