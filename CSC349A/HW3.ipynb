# %%
x = 1.2
p0 = 2
p1 = p0 + (x-1)/4
p2 = p1 - ((x-1)**2)/64
p3 = p2 +((x-1)**3)/512

print(p0)
print(p1)
print(p2)
print(p3)

ea1 = (p1-p0)/p1
ea2 = (p2-p1)/p2
ea3 = (p3-p2)/p3
print(ea1)
print(ea2)
print(ea3)

true = 2.04939015319192
print((true - p3)/true)

#1 = -1 mantissa
#3114 = 409
#1 = -1 exponent
#6 for exponent

#-409**-6
sign = -1
ex_sign = -1
f = 0
base = 5
nums = [3,1,0,4]
# Out:
# 2
# 2.05
# 2.049375
# 2.049390625
# 0.02439024390243894
# -0.00030497102775230286
# 7.62421756470883e-06
# -2.302187699230378e-07
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 34
#      32 nums = [3,1,0,4]
#      33 for index, item in enumerate(nums):
# ---> 34     f += nums * 5 **(-index - 1)
#      35 print(f)
#
# TypeError: can't multiply sequence by non-int of type 'float'
